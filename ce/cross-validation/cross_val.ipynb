# %%
# from MuyGPyS import config
# config.update("muygpys_jax_enabled", False)

import numpy as np
import pandas as pd
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from MuyGPyS.examples.classify import do_classify
from MuyGPyS.gp.deformation import F2, Isotropy, l2
from MuyGPyS.gp.hyperparameter import Parameter, Parameter as ScalarParam
from MuyGPyS.gp.kernels import RBF, Matern
from MuyGPyS.gp.noise import HomoscedasticNoise
from MuyGPyS.optimize import Bayes_optimize, L_BFGS_B_optimize
from MuyGPyS.optimize.loss import LossFn, cross_entropy_fn, looph_fn
# Out:
# /home/eleh/miniconda3/envs/muygps/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
# data_path = ['norm_11.csv','norm_1.csv', 'norm_21.csv', 'raw_image_data.csv']
data_path = [ 'raw_image_data.csv']
# get rid of "../data/data-norm/"
norm_data_names = data_path
norm_data_names
# Out:
# ['raw_image_data.csv']

# %%
def generate_onehot_value(values):
    onehot = []
    for val in values:
        if val == 0:
            onehot.append([1., -1.])
        elif val == 1:
            onehot.append([-1., 1.])
    return onehot

# %%
nn_kwargs_exact = {"nn_method": "exact", "algorithm": "ball_tree"}

nn_kwargs_hnsw = {"nn_method": "hnsw"}

k_kwargs_rbf ={
            "kernel": RBF(
                 deformation=Isotropy(
                     metric=F2,
                 length_scale=Parameter(1.0, (1e-2, 1e2)),
                 ),
            ),
            "noise": HomoscedasticNoise(1e-5),
            }
k_kwargs_mattern= { "kernel": Matern(
             smoothness=ScalarParam(0.5),
             deformation=Isotropy(
                 metric=F2,
                 length_scale=Parameter(1.0, (1e-2, 1e2)),
             ),
         ),
         "noise": HomoscedasticNoise(1e-5),
         }

# %% [markdown]
# ### Cross Validation
# We use Monte-Carlo Cross Validation to investigate the variability in the performance of MuyGPs with respect to the raw data in comparison to the normalized data.

# %%
nn_kwargs_hnsw = {"nn_method": "hnsw"}

# k_kwargs_mattern= { "kernel": Matern(
#              smoothness=ScalarParam(0.858571),
#              deformation=Isotropy(
#                  metric=F2,
#                  length_scale=Parameter(.756327, (1e-2, 1e2)),
#              ),
#          ),
#          "noise": HomoscedasticNoise(0.244898),
#          }

k_kwargs_mattern= { "kernel": Matern(
             smoothness=ScalarParam(0.5),
             deformation=Isotropy(
                 metric=l2,
                 length_scale=Parameter(10.0, (1e-2, 1e2)),
             ),
         ),
         "noise": HomoscedasticNoise(1e-6),
         }

# %%
import pickle

m = 100 # cross validation size
train_sizes = [0.8 for i in range(m)]
# read in data
# path = 'norm_21.csv'
# path = 'raw_image_data.csv'
path = 'nthroot_0.3103.csv'
path1 = '../../data/data-norm/max-only/' + path
data = pd.read_csv(path1,na_values='-')
data.fillna(0,inplace=True)
data_label = ''.join(path.split('.')[:2])
truth_labels = data.iloc[:, 0].values
image_data = data.iloc[:, 1:].values

accuracy = {'raw-data':[], 'rroot-03103':[]}
# i = 0   # run one at a time since MUYGPS won't left me run multiple at once
for i,size in enumerate(train_sizes):
    X_train, X_test, y_train, y_test = train_test_split(image_data, truth_labels, train_size=size)


    print("=============== ", data_label, " ===============")
    print('Training data:', len(y_train[y_train==0]), 'single stars and', len(y_train[y_train==1]), 'blended stars')
    print('Testing data:', len(y_test[y_test==0]), 'single stars and', len(y_test[y_test==1]), 'blended stars')

    onehot_train, onehot_test = generate_onehot_value(y_train), generate_onehot_value(y_test)

    train = {'input': X_train, 'output': onehot_train, 'lookup': y_train}
    test = {'input': X_test, 'output': onehot_test, 'lookup': y_test}

    print("Running Classifier on", data_label)
    #Switch verbose to True for more output


    muygps, nbrs_lookup, surrogate_predictions = do_classify(
                                test_features=np.array(test['input']), 
                                train_features=np.array(train['input']), 
                                train_labels=np.array(train['output']), 
                                nn_count=35,
                                batch_count=200,
                                loss_fn=looph_fn,
                                opt_fn=L_BFGS_B_optimize,
                                k_kwargs=k_kwargs_mattern,
                                nn_kwargs=nn_kwargs_hnsw,
                                verbose=False)
    predicted_labels = np.argmax(surrogate_predictions, axis=1)
    accur = np.around((np.sum(predicted_labels == np.argmax(test["output"], axis=1))/len(predicted_labels))*100, 3)
    if path == 'raw_image_data.csv':
        accuracy['raw-data'].append(accur)
    else:
        accuracy['rroot-03103'].append(accur)
    print(f"Total accuracy at Iter {i+1}: {accur}%")

    # check if accuracy file exists, if not save it as a new file and if it does exist, append to it
    if path == 'raw_image_data.csv':
        saveto = './cv-results/raw-data-cv-results.pkl'
    else:
        saveto = './cv-results/rroot-03103-cv-results.pkl'
    try:
        with open(saveto, 'rb') as f:
            acc = pickle.load(f)
            acc.update(accuracy)
        with open(saveto, 'wb') as f:
            pickle.dump(acc, f)
    except:
        with open(saveto, 'wb') as f:
            pickle.dump(accuracy, f)
# Out:
# ===============  nthroot_03103  ===============
# Training data: 12137 single stars and 9664 blended stars
# Testing data: 2972 single stars and 2479 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 1: 82.26%
# ===============  nthroot_03103  ===============
# Training data: 12084 single stars and 9717 blended stars
# Testing data: 3025 single stars and 2426 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 2: 82.774%
# ===============  nthroot_03103  ===============
# Training data: 12072 single stars and 9729 blended stars
# Testing data: 3037 single stars and 2414 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 3: 81.343%
# ===============  nthroot_03103  ===============
# Training data: 12111 single stars and 9690 blended stars
# Testing data: 2998 single stars and 2453 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 4: 82.554%
# ===============  nthroot_03103  ===============
# Training data: 12107 single stars and 9694 blended stars
# Testing data: 3002 single stars and 2449 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 5: 82.278%
# ===============  nthroot_03103  ===============
# Training data: 12108 single stars and 9693 blended stars
# Testing data: 3001 single stars and 2450 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 6: 82.113%
# ===============  nthroot_03103  ===============
# Training data: 12035 single stars and 9766 blended stars
# Testing data: 3074 single stars and 2377 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 7: 82.462%
# ===============  nthroot_03103  ===============
# Training data: 12089 single stars and 9712 blended stars
# Testing data: 3020 single stars and 2431 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 8: 81.618%
# ===============  nthroot_03103  ===============
# Training data: 12126 single stars and 9675 blended stars
# Testing data: 2983 single stars and 2468 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 9: 81.691%
# ===============  nthroot_03103  ===============
# Training data: 12052 single stars and 9749 blended stars
# Testing data: 3057 single stars and 2394 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 10: 81.526%
# ===============  nthroot_03103  ===============
# Training data: 12118 single stars and 9683 blended stars
# Testing data: 2991 single stars and 2460 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 11: 81.728%
# ===============  nthroot_03103  ===============
# Training data: 12126 single stars and 9675 blended stars
# Testing data: 2983 single stars and 2468 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 12: 81.013%
# ===============  nthroot_03103  ===============
# Training data: 12069 single stars and 9732 blended stars
# Testing data: 3040 single stars and 2411 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 13: 83.012%
# ===============  nthroot_03103  ===============
# Training data: 12068 single stars and 9733 blended stars
# Testing data: 3041 single stars and 2410 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 14: 82.664%
# ===============  nthroot_03103  ===============
# Training data: 12063 single stars and 9738 blended stars
# Testing data: 3046 single stars and 2405 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 15: 81.948%
# ===============  nthroot_03103  ===============
# Training data: 12105 single stars and 9696 blended stars
# Testing data: 3004 single stars and 2447 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 16: 82.022%
# ===============  nthroot_03103  ===============
# Training data: 12074 single stars and 9727 blended stars
# Testing data: 3035 single stars and 2416 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 17: 81.526%
# ===============  nthroot_03103  ===============
# Training data: 12093 single stars and 9708 blended stars
# Testing data: 3016 single stars and 2435 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 18: 81.967%
# ===============  nthroot_03103  ===============
# Training data: 12105 single stars and 9696 blended stars
# Testing data: 3004 single stars and 2447 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 19: 81.948%
# ===============  nthroot_03103  ===============
# Training data: 11987 single stars and 9814 blended stars
# Testing data: 3122 single stars and 2329 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 20: 82.48%
# ===============  nthroot_03103  ===============
# Training data: 12038 single stars and 9763 blended stars
# Testing data: 3071 single stars and 2380 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 21: 82.315%
# ===============  nthroot_03103  ===============
# Training data: 12043 single stars and 9758 blended stars
# Testing data: 3066 single stars and 2385 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 22: 80.719%
# ===============  nthroot_03103  ===============
# Training data: 12063 single stars and 9738 blended stars
# Testing data: 3046 single stars and 2405 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 23: 81.636%
# ===============  nthroot_03103  ===============
# Training data: 12025 single stars and 9776 blended stars
# Testing data: 3084 single stars and 2367 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 24: 82.737%
# ===============  nthroot_03103  ===============
# Training data: 12004 single stars and 9797 blended stars
# Testing data: 3105 single stars and 2346 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 25: 83.453%
# ===============  nthroot_03103  ===============
# Training data: 12106 single stars and 9695 blended stars
# Testing data: 3003 single stars and 2448 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 26: 81.581%
# ===============  nthroot_03103  ===============
# Training data: 12080 single stars and 9721 blended stars
# Testing data: 3029 single stars and 2422 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 27: 81.691%
# ===============  nthroot_03103  ===============
# Training data: 12139 single stars and 9662 blended stars
# Testing data: 2970 single stars and 2481 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 28: 81.655%
# ===============  nthroot_03103  ===============
# Training data: 12090 single stars and 9711 blended stars
# Testing data: 3019 single stars and 2432 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 29: 83.177%
# ===============  nthroot_03103  ===============
# Training data: 12126 single stars and 9675 blended stars
# Testing data: 2983 single stars and 2468 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 30: 82.187%
# ===============  nthroot_03103  ===============
# Training data: 12126 single stars and 9675 blended stars
# Testing data: 2983 single stars and 2468 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 31: 81.526%
# ===============  nthroot_03103  ===============
# Training data: 12080 single stars and 9721 blended stars
# Testing data: 3029 single stars and 2422 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 32: 81.802%
# ===============  nthroot_03103  ===============
# Training data: 12061 single stars and 9740 blended stars
# Testing data: 3048 single stars and 2403 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 33: 83.269%
# ===============  nthroot_03103  ===============
# Training data: 12041 single stars and 9760 blended stars
# Testing data: 3068 single stars and 2383 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 34: 82.847%
# ===============  nthroot_03103  ===============
# Training data: 12068 single stars and 9733 blended stars
# Testing data: 3041 single stars and 2410 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 35: 81.728%
# ===============  nthroot_03103  ===============
# Training data: 12013 single stars and 9788 blended stars
# Testing data: 3096 single stars and 2355 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 36: 82.278%
# ===============  nthroot_03103  ===============
# Training data: 12056 single stars and 9745 blended stars
# Testing data: 3053 single stars and 2398 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 37: 82.499%
# ===============  nthroot_03103  ===============
# Training data: 12046 single stars and 9755 blended stars
# Testing data: 3063 single stars and 2388 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 38: 82.774%
# ===============  nthroot_03103  ===============
# Training data: 12099 single stars and 9702 blended stars
# Testing data: 3010 single stars and 2441 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 39: 82.81%
# ===============  nthroot_03103  ===============
# Training data: 12094 single stars and 9707 blended stars
# Testing data: 3015 single stars and 2436 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 40: 82.022%
# ===============  nthroot_03103  ===============
# Training data: 12154 single stars and 9647 blended stars
# Testing data: 2955 single stars and 2496 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 41: 81.912%
# ===============  nthroot_03103  ===============
# Training data: 12054 single stars and 9747 blended stars
# Testing data: 3055 single stars and 2396 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 42: 81.967%
# ===============  nthroot_03103  ===============
# Training data: 12011 single stars and 9790 blended stars
# Testing data: 3098 single stars and 2353 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 43: 83.709%
# ===============  nthroot_03103  ===============
# Training data: 12123 single stars and 9678 blended stars
# Testing data: 2986 single stars and 2465 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 44: 81.691%
# ===============  nthroot_03103  ===============
# Training data: 12061 single stars and 9740 blended stars
# Testing data: 3048 single stars and 2403 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 45: 82.187%
# ===============  nthroot_03103  ===============
# Training data: 12111 single stars and 9690 blended stars
# Testing data: 2998 single stars and 2453 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 46: 82.132%
# ===============  nthroot_03103  ===============
# Training data: 12062 single stars and 9739 blended stars
# Testing data: 3047 single stars and 2404 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 47: 82.352%
# ===============  nthroot_03103  ===============
# Training data: 12125 single stars and 9676 blended stars
# Testing data: 2984 single stars and 2467 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 48: 82.278%
# ===============  nthroot_03103  ===============
# Training data: 12060 single stars and 9741 blended stars
# Testing data: 3049 single stars and 2402 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 49: 82.48%
# ===============  nthroot_03103  ===============
# Training data: 12045 single stars and 9756 blended stars
# Testing data: 3064 single stars and 2387 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 50: 82.205%
# ===============  nthroot_03103  ===============
# Training data: 12075 single stars and 9726 blended stars
# Testing data: 3034 single stars and 2417 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 51: 82.37%
# ===============  nthroot_03103  ===============
# Training data: 12113 single stars and 9688 blended stars
# Testing data: 2996 single stars and 2455 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 52: 82.645%
# ===============  nthroot_03103  ===============
# Training data: 12142 single stars and 9659 blended stars
# Testing data: 2967 single stars and 2484 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 53: 81.691%
# ===============  nthroot_03103  ===============
# Training data: 12120 single stars and 9681 blended stars
# Testing data: 2989 single stars and 2462 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 54: 82.003%
# ===============  nthroot_03103  ===============
# Training data: 12098 single stars and 9703 blended stars
# Testing data: 3011 single stars and 2440 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 55: 81.471%
# ===============  nthroot_03103  ===============
# Training data: 12052 single stars and 9749 blended stars
# Testing data: 3057 single stars and 2394 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 56: 82.517%
# ===============  nthroot_03103  ===============
# Training data: 12085 single stars and 9716 blended stars
# Testing data: 3024 single stars and 2427 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 57: 82.444%
# ===============  nthroot_03103  ===============
# Training data: 12053 single stars and 9748 blended stars
# Testing data: 3056 single stars and 2395 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 58: 81.93%
# ===============  nthroot_03103  ===============
# Training data: 12015 single stars and 9786 blended stars
# Testing data: 3094 single stars and 2357 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 59: 82.26%
# ===============  nthroot_03103  ===============
# Training data: 12082 single stars and 9719 blended stars
# Testing data: 3027 single stars and 2424 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 60: 82.535%
# ===============  nthroot_03103  ===============
# Training data: 12081 single stars and 9720 blended stars
# Testing data: 3028 single stars and 2423 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 61: 82.113%
# ===============  nthroot_03103  ===============
# Training data: 12040 single stars and 9761 blended stars
# Testing data: 3069 single stars and 2382 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 62: 81.673%
# ===============  nthroot_03103  ===============
# Training data: 12083 single stars and 9718 blended stars
# Testing data: 3026 single stars and 2425 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 63: 81.013%
# ===============  nthroot_03103  ===============
# Training data: 12088 single stars and 9713 blended stars
# Testing data: 3021 single stars and 2430 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 64: 82.609%
# ===============  nthroot_03103  ===============
# Training data: 11995 single stars and 9806 blended stars
# Testing data: 3114 single stars and 2337 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 65: 81.967%
# ===============  nthroot_03103  ===============
# Training data: 12074 single stars and 9727 blended stars
# Testing data: 3035 single stars and 2416 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 66: 82.535%
# ===============  nthroot_03103  ===============
# Training data: 12108 single stars and 9693 blended stars
# Testing data: 3001 single stars and 2450 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 67: 81.581%
# ===============  nthroot_03103  ===============
# Training data: 12064 single stars and 9737 blended stars
# Testing data: 3045 single stars and 2406 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 68: 81.636%
# ===============  nthroot_03103  ===============
# Training data: 12110 single stars and 9691 blended stars
# Testing data: 2999 single stars and 2452 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 69: 81.783%
# ===============  nthroot_03103  ===============
# Training data: 12108 single stars and 9693 blended stars
# Testing data: 3001 single stars and 2450 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 70: 82.517%
# ===============  nthroot_03103  ===============
# Training data: 12117 single stars and 9684 blended stars
# Testing data: 2992 single stars and 2459 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 71: 81.82%
# ===============  nthroot_03103  ===============
# Training data: 12100 single stars and 9701 blended stars
# Testing data: 3009 single stars and 2442 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 72: 81.802%
# ===============  nthroot_03103  ===============
# Training data: 12118 single stars and 9683 blended stars
# Testing data: 2991 single stars and 2460 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 73: 80.994%
# ===============  nthroot_03103  ===============
# Training data: 12114 single stars and 9687 blended stars
# Testing data: 2995 single stars and 2456 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 74: 82.058%
# ===============  nthroot_03103  ===============
# Training data: 12062 single stars and 9739 blended stars
# Testing data: 3047 single stars and 2404 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 75: 82.077%
# ===============  nthroot_03103  ===============
# Training data: 12083 single stars and 9718 blended stars
# Testing data: 3026 single stars and 2425 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 76: 82.095%
# ===============  nthroot_03103  ===============
# Training data: 12085 single stars and 9716 blended stars
# Testing data: 3024 single stars and 2427 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 77: 82.682%
# ===============  nthroot_03103  ===============
# Training data: 12094 single stars and 9707 blended stars
# Testing data: 3015 single stars and 2436 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 78: 82.187%
# ===============  nthroot_03103  ===============
# Training data: 12113 single stars and 9688 blended stars
# Testing data: 2996 single stars and 2455 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 79: 82.058%
# ===============  nthroot_03103  ===============
# Training data: 12080 single stars and 9721 blended stars
# Testing data: 3029 single stars and 2422 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 80: 82.242%
# ===============  nthroot_03103  ===============
# Training data: 12059 single stars and 9742 blended stars
# Testing data: 3050 single stars and 2401 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 81: 81.875%
# ===============  nthroot_03103  ===============
# Training data: 12095 single stars and 9706 blended stars
# Testing data: 3014 single stars and 2437 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 82: 81.398%
# ===============  nthroot_03103  ===============
# Training data: 12022 single stars and 9779 blended stars
# Testing data: 3087 single stars and 2364 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 83: 82.59%
# ===============  nthroot_03103  ===============
# Training data: 12109 single stars and 9692 blended stars
# Testing data: 3000 single stars and 2451 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 84: 81.086%
# ===============  nthroot_03103  ===============
# Training data: 12032 single stars and 9769 blended stars
# Testing data: 3077 single stars and 2374 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 85: 82.627%
# ===============  nthroot_03103  ===============
# Training data: 12074 single stars and 9727 blended stars
# Testing data: 3035 single stars and 2416 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 86: 82.572%
# ===============  nthroot_03103  ===============
# Training data: 12100 single stars and 9701 blended stars
# Testing data: 3009 single stars and 2442 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 87: 82.389%
# ===============  nthroot_03103  ===============
# Training data: 12121 single stars and 9680 blended stars
# Testing data: 2988 single stars and 2463 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 88: 82.187%
# ===============  nthroot_03103  ===============
# Training data: 12060 single stars and 9741 blended stars
# Testing data: 3049 single stars and 2402 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 89: 82.278%
# ===============  nthroot_03103  ===============
# Training data: 12090 single stars and 9711 blended stars
# Testing data: 3019 single stars and 2432 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 90: 81.691%
# ===============  nthroot_03103  ===============
# Training data: 12141 single stars and 9660 blended stars
# Testing data: 2968 single stars and 2483 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 91: 81.6%
# ===============  nthroot_03103  ===============
# Training data: 12097 single stars and 9704 blended stars
# Testing data: 3012 single stars and 2439 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 92: 82.278%
# ===============  nthroot_03103  ===============
# Training data: 12095 single stars and 9706 blended stars
# Testing data: 3014 single stars and 2437 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 93: 82.242%
# ===============  nthroot_03103  ===============
# Training data: 12051 single stars and 9750 blended stars
# Testing data: 3058 single stars and 2393 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 94: 81.985%
# ===============  nthroot_03103  ===============
# Training data: 12104 single stars and 9697 blended stars
# Testing data: 3005 single stars and 2446 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 95: 81.398%
# ===============  nthroot_03103  ===============
# Training data: 12122 single stars and 9679 blended stars
# Testing data: 2987 single stars and 2464 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 96: 81.618%
# ===============  nthroot_03103  ===============
# Training data: 12072 single stars and 9729 blended stars
# Testing data: 3037 single stars and 2414 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 97: 81.783%
# ===============  nthroot_03103  ===============
# Training data: 12116 single stars and 9685 blended stars
# Testing data: 2993 single stars and 2458 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 98: 81.71%
# ===============  nthroot_03103  ===============
# Training data: 12033 single stars and 9768 blended stars
# Testing data: 3076 single stars and 2375 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 99: 82.04%
# ===============  nthroot_03103  ===============
# Training data: 12118 single stars and 9683 blended stars
# Testing data: 2991 single stars and 2460 blended stars
# Running Classifier on nthroot_03103
# Total accuracy at Iter 100: 81.563%

# %%
# pickle save accuracy
import pickle
with open(saveto, 'wb') as f:
    pickle.dump(accuracy, f)
